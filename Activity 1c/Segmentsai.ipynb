# %%
# !pip install --upgrade segments-ai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 44 kB 2.2 MB/s
# ...
#   Created wheel for segments-ai: filename=segments_ai-1.0.3-py3-none-any.whl size=33262 sha256=69a3f8a4ea6f9fe502ecf07c9f685b38609644ec0b038958831cc07abe0d9792
#   Stored in directory: /root/.cache/pip/wheels/3f/ac/42/937ee1b30513cb7dbd7264fffe027004993a4b2e71eb981b5c
# Successfully built segments-ai
# ...

# %%
# pip install segments-ai
from segments import SegmentsClient, SegmentsDataset
from segments.utils import export_dataset

# %%
# Initialize a SegmentsDataset from the release file
client = SegmentsClient('xxxx')

dataset_identifier = "Dayrm/REY_roi_manualSelection1"
name = "v0.1"
client.add_release(dataset_identifier, name)
# Out:
# Release(uuid='56f90653-43ab-46b8-aea7-49d0a79bb0ca', name='v0.1', description='', release_type='JSON', attributes=URL(url=None), status='PENDING', created_at='2022-08-10T06:05:09.894654Z', samples_count=605)

# %%
release = client.get_release(dataset_identifier, name)
dataset = SegmentsDataset(release, labelset='ground-truth', filter_by=['labeled', 'reviewed'])
# Out:
# Initializing dataset...
# Preloading all samples. This may take a while...
#   0%|          | 0/529 [00:00<?, ?it/s]WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
#  12%|█▏        | 61/529 [00:00<00:03, 122.90it/s]WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# ...

# %%
# Export to COCO panoptic format
export_dataset(dataset, export_format='yolo')
# Out:
# Exporting dataset. This may take a while...
# 100%|██████████| 529/529 [00:00<00:00, 2412.89it/s]
# Exported. Images and labels in segments/Dayrm_REY_roi_manualSelection1/v0.1
# 'segments/Dayrm_REY_roi_manualSelection1/v0.1'

# %%
# !zip -r '/content/dataset_roiManualSelection1.zip' '/content/segments/Dayrm_REY_roi_manualSelection1/v0.1'
# Out:
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ (stored 0%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_90_Psic_033Ev5.pdf_pg-33.jpg (deflated 8%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_0_Psic_233Ev5.pdf_pg-18.jpg (deflated 5%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_90_Psic_130Ev2.pdf_pg-18.jpg (deflated 0%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_90_Psic_116Ev4.pdf_pg-25.txt (deflated 5%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_90_Psic_209Ev1.pdf_pg-20.jpg (deflated 9%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_0_Psic_524Ev1.pdf_pg-23.txt (deflated 5%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_0_Psic_141Ev5.pdf_pg-27.jpg (deflated 5%)
#   adding: content/segments/Dayrm_REY_roi_manualSelection1/v0.1/ROI_0_Psic_344Ev2-r.png (stored 0%)
# ...

# %%
from google.colab import files
files.download('/content/dataset_roiManualSelection1.zip')
